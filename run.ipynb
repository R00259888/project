# %%
# !python3 -m pip install tqdm==4.67.3

# %%
import google.colab
google.colab.drive.mount("/content/drive", force_remount=True)

# %%
# !cd drive/MyDrive/project && chmod +x run.sh && export COLAB_MODE=1 && ./run.sh
